# %% [markdown]
# # **INTRODUCTION TO FINANCE**

# %% [markdown]
# **Finance** is the field of study concerned with managing money, investments, and financial resources. It plays an essential role in the functioning of individuals, businesses, financial institutions, and governments.

# %% [markdown]
# The main objective of finance is to determine how money should be obtained, allocated, invested, and managed over time while considering risk and return.

# %% [markdown]
# ## **Why is Finance Important?**
# Finance helps individuals and organizations make better decisions about their financial resources

# %% [markdown]
# For example:
#
# An individual decides how much to save, spend, or invest.
# A company decides whether to borrow money or use its own capital.
# A business evaluates whether a new investment project is profitable.
# A government manages public revenues, expenditures, and debt.

# %% [markdown]
# ## **The Three Main Areas of Finance**

# %% [markdown]
# Finance is generally divided into three major area
#
# **1. *Personal Finance***
#
# *Personal finance* concerns the management of an individual's or household's money.
#
# It includes:
#
# - Income and expenses
# - Saving
# - Budgeting
# - Loans and debt
# - Insurance
# - Investments
# - Retirement planning
#
# **2. *Corporate Finance***
#
# *Corporate finance* focuses on the financial decisions made by businesses.
#
# Companies need to decide:
#
# How to finance their activities
# Which projects to invest in
# How to manage cash
# How much debt to use
# How to maximize the value of the company
#
# Important concepts include capital budgeting, financing decisions, working capital management, and dividend policy.
