# %% [markdown]
# # Python Fundamentals
#
# This folder in the **ACLNOWLEDGE** repository is my learning path to study **Python Fundamentals** step by step.
#
# This course is based on the **IBM Python Fundamentals course on edX**.

# %%
# This is my first Python comment
print("Hello, Python!")
