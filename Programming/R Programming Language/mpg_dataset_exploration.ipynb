# %% [markdown]
# # Exploring the Built-in `mpg` Dataset

# %% [markdown]
# ## Dataset documentation — output of `?mpg`
#
# **Fuel economy data from 1999 to 2008 for 38 popular models of cars**
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes available on <https://fueleconomy.gov/>. It contains only models which had a new release every year between 1999 and 2008 - this was used as a proxy for the popularity of the car.
#
# ### Usage
#
# ```r
# mpg
# ```
#
# ### Format
#
# A data frame with 234 rows and 11 variables:
#
# - `manufacturer` — manufacturer name
# - `model` — model name
# - `displ` — engine displacement, in litres
# - `year` — year of manufacture
# - `cyl` — number of cylinders
# - `trans` — type of transmission
# - `drv` — the type of drive train, where f = front-wheel drive, r = rear wheel drive, 4 = 4wd
# - `cty` — city miles per gallon
# - `hwy` — highway miles per gallon
# - `fl` — fuel type
# - `class` — type of car

# %%
# Load the tidyverse packages
library(tidyverse)

# %% [markdown]
# ### Console output
#
# ```text
# library(tidyverse)
# ── Attaching core tidyverse packages ──
# ✔ dplyr
# ✔ readr
# ✔ forcats
# ✔ stringr
# ✔ ggplot2
# ✔ tibble
# ✔ lubridate
# ✔ tidyr
# ✔ purrr
# ```
#
# > The exact package versions and conflict messages can vary depending on your R/tidyverse installation.

# %%
# Load the mpg dataset explicitly
data(mpg)

# Open the dataset in a spreadsheet-like viewer
View(mpg)

# %%
# Inspect the dataset directly in the console
mpg

# %%
# Check the structure of the dataset
str(mpg)

# %%
# Display the dimensions: number of rows and columns
dim(mpg)

# %%
# Display the column names
names(mpg)

# %% [markdown]
# ### Important correction
#
# `data()` by itself lists available datasets; it does not specifically select `mpg`. For clarity, use `data(mpg)` before working with the dataset. Because `mpg` is included with **ggplot2**, it is also available after loading `tidyverse`.
